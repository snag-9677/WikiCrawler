# %%
import pickle
import networkx as nx

# %%
pickle_path = r"wiki_pickle\graph_0.pkl"

# %%
# Load the graph
with open(pickle_path, 'rb') as f:
    _graph:dict = pickle.load(f)
    
keys_to_keep = set(list(_graph.keys()))

# %%
# Loop through the graph and remove any edge from all nodes that is not in the keys_to_keep
for key in _graph.keys():
    _graph[key] = set(_graph[key]).intersection(keys_to_keep)

# Remove all keys which have less than 3 edges for a better network view
for key in list(_graph.keys()).copy():
    if len(_graph[key]) < 3:
        del _graph[key]

# %%
G = nx.Graph(_graph)
G

# %%
# Draw the graph, make marker size smaller
nx.draw(G, with_labels=True, node_size=50, font_size=8, width=0.1, node_color='b')

# %%
# Load isolated nodes and see which ones they are 
with open(r"wiki_pickle\nodes_0.pkl", 'rb') as f:
    nodes = pickle.load(f)

# %%
_nodes_to_print = [10218, 23870, 9612, 25799, 5248, 5198]

for _n in _nodes_to_print:
    print(nodes[_n])
# Out:
# {'url': 'https://en.wikipedia.org/wiki/Douglas_Adams', 'data': '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Douglas Adams","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Douglas_Adams","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q42","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q42","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2001-11-09T23:50:08Z","dateModified":"2023-10-18T23:16:49Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/c\\/c0\\/Douglas_adams_portrait_cropped.jpg","headline":"English science fiction writer and humourist"}'}
# {'url': 'https://en.wikipedia.org/wiki/Mainland_China', 'data': '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Mainland China","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Mainland_China","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q19188","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q19188","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2002-06-05T23:14:22Z","dateModified":"2023-09-08T09:38:30Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/b\\/b4\\/MainlandChina.png","headline":"geopolitical area under the jurisdiction of the People\'s Republic of China, excluding Special Administrative Regions"}'}
# {'url': 'https://en.wikipedia.org/wiki/Slashdot', 'data': '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Slashdot","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Slashdot","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q59083","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q59083","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2001-10-01T11:29:41Z","dateModified":"2023-10-19T08:17:17Z","headline":"technology-related news website"}'}
# {'url': 'https://en.wikipedia.org/wiki/Vox_(website)', 'data': '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Vox (website)","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Vox_(website)","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q20877087","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q20877087","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2014-12-26T18:58:22Z","dateModified":"2023-10-16T13:59:38Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/a\\/a2\\/Vox_logo.svg","headline":"American news website"}'}
# {'url': 'https://en.wikipedia.org/wiki/Age_of_Enlightenment', 'data': '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Age of Enlightenment","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Age_of_Enlightenment","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q12539","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q12539","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2001-09-27T08:01:50Z","dateModified":"2023-10-21T13:27:51Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/c\\/cb\\/Salon_de_Madame_Geoffrin.jpg","headline":"European cultural movement of the 17th and 18th centuries"}'}
# {'url': 'https://en.wikipedia.org/wiki/Katherine_Maher', 'data': '{"@context":"https:\\/\\/schema.org","@type":"Article","name":"Katherine Maher","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/Katherine_Maher","sameAs":"http:\\/\\/www.wikidata.org\\/entity\\/Q23034479","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q23034479","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/static\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2016-03-11T03:34:17Z","dateModified":"2023-10-11T00:36:42Z","image":"https:\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/c\\/c7\\/Katherine_Maher_%28cropped%29.jpg","headline":"former chief executive officer and executive director of the Wikimedia Foundation"}'}
